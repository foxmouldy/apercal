# %%
from apercal import lib
lib.setup_logger('info', logfile='/home/frank/mplot.log', quiet=True)
import pylab as pl
# %matplotlib inline
import os
# Out:
# Setup logger with lib.setup_logger()
# Logging to file. To see the log in a bash window use the following command:
# tail -n +1 -f /home/frank/mplot.log

# %%
from apercal import mplot

# %%
mplot.uvplt(vis='/home/frank/tutorials/tutorial-ngc3998/cal1.uv', r=5, nxy='3,3', select='-auto')
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
mplot.uvspec(vis="/home/frank/tutorial-ngc4278/cal1.uv", r=5, nxy='1,1', 
             interval=1000, select='-auto', options="avall,nobase")
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
mplot.uvspec(vis="/home/frank/tutorial-ngc4278/src.uv", r=5, nxy='1,1', 
             interval=1000, select='-auto', options="avall,nobase")
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">
