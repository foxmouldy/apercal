# %%
from apercal import lib
lib.setup_logger('info', logfile='/home/frank/mplot.log', quiet=True)
import pylab as pl
# %matplotlib inline
import os
# Out:
# Don't forget to setup logger with lib.setup_logger()
# Logging to file. To see the log in a bash window use the following command:
# tail -n +1 -f /home/frank/cinplot.log

# %%
from apercal import mplot

# %%
mplot.uvplt(vis='/home/frank/tutorial-ugc9519/cal1.uv', r=5, nxy='3,3')
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
mplot.uvspec(vis="/home/frank/tutorial-ugc9519/src.uv", r=5, nxy='1,1', interval=1000, options="avall,nobase")
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">
