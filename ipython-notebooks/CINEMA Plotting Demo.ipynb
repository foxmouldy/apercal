# %%
from apercal import lib
lib.setup_logger('debug', logfile='/home/frank/cinplot.log', quiet=True)
import pylab as pl
# %matplotlib inline
import os
# Out:
# Logging to file. To see the log in a bash window use the following command:
# tail -n +1 -f /home/frank/cinplot.log

# %%
from apercal import mplot

# %%
mplot.uvplt(vis='/home/frank/cinema-tutorial/cal1.uv', r=5, nxy='3,3')
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">

# %%
mplot.uvspec(vis='/home/frank/cinema-tutorial/cal1.uv', r=5, nxy='3,3', interval=1000)
# Out:
# <video controls alt="test" src="data:video/x-m4v;base64,...">
