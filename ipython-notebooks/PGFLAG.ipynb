# %% [markdown]
# # PGFLAG in the Notebook
#
# **``PGFLAG``**, like any other **``MIRIAD``** task, can be hooked in the IPython Notebook. In this example define the PGFLAG task and run it with a few test parameters.
#
# In this case we use the logging at the *default* level, since this allows us to see the full output of **``PGFLAG``**.

# %%
# Header Cell
from apercal import lib
from apercal import mplot
logger = lib.setup_logger('debug', logfile='/home/frank/flagging.log')
import pylab as pl
# %matplotlib inline
import os
pgflag = lib.miriad('pgflag')
# Out:
# root - INFO : Logging started!
# root - INFO : To see the log in a bash window use the following command:
# root - INFO : tail -n +1 -f /home/frank/flagging.log
# Setup logger with lib.setup_logger()

# %% [markdown]
# In this example we use the SumThreshold method from Offringa et al,2010, MNRAS 405,155. The important parameters are:
#
# ```
# flagpar
#          Parameters for SumThreshold flagging (and dusting)
#          (see Offringa et al,2010, MNRAS 405,155)
#          1 : Threshold in estimated sigma's (estimated using the
#              median absolute deviation), default 7
#          2 : Convolution size for channel direction (in channels), used
#              to generate a smooth background, default 1. Zero disables
#              convolution in the channel direction.
#          3 : Convolution size for time direction (in integrations), used
#              to generate a smooth background, default 1. Zero disables
#              convolution in the time direction
#          4 : Number of iterations of the convolve/subtract/threshold
#              operation.The threshold level decreases by a factor of two
#              each iteration. Default 3
#          5 : Power of two of the maximum number of points used in the
#              SumThreshold operation (e.g., 5 -> 32 points). Default 5.
#          6 : Dust the plot - flag points with less than flagpar(6)
#              unflagged neighbours. Useful range 1-4, default 3.
# ```
#
# As usual, change to the working directory so that the filenames can be local.

# %%
path = '/home/frank/tutorials/tutorial-ngc3998/'
vis='s2.uv'
os.chdir(path)

# %% [markdown]
# Set up the flagging parameters.

# %%
pgflag.vis = vis
pgflag.command = "\'<\'"
pgflag.stokes = 'qq'
pgflag.options = "nodisp"
pgflag.flagpar = '6,2,2,2,4,2'

# %% [markdown]
# Execute the task:

# %%
output = pgflag.go()
# Out:
# masher - INFO : pgflag flagpar=6,2,2,2,4,2 stokes=qq command='<' options=nodisp vis=s2.uv
# basher - DEBUG : pgflag flagpar=6,2,2,2,4,2 stokes=qq command='<' options=nodisp vis=s2.uv
# basher - DEBUG : Command = pgflag flagpar=6,2,2,2,4,2 stokes=qq command='<' options=nodisp vis=s2.uv
# basher - DEBUG :
#
# pgflag: CVS Revision 1.5, 2012/07/06 12:36:39 UTC
#
# Do SumThreshold operation on baseline   1   2
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   3
#   0.9% of the data on this baseline is now flagged
#   1.1% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   3
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   4
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   4
#   0.9% of the data on this baseline is now flagged
#   1.1% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3   4
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   5
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   5
#   1.0% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3   5
#   1.0% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4   5
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   7
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   7
#   1.2% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3   7
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4   7
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5   7
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   8
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   8
#   1.1% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3   8
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4   8
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5   8
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7   8
#   1.2% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1   9
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2   9
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3   9
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4   9
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5   9
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7   9
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8   9
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1  10
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2  10
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3  10
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4  10
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5  10
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7  10
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8  10
#   1.2% of the data on this baseline is now flagged
#   1.6% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   9  10
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1  11
#   1.2% of the data on this baseline is now flagged
#   1.8% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2  11
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3  11
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4  11
#   0.9% of the data on this baseline is now flagged
#   1.1% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5  11
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7  11
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8  11
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   9  11
#   1.2% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  10  11
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1  12
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2  12
#   1.1% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3  12
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4  12
#   1.2% of the data on this baseline is now flagged
#   1.6% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5  12
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7  12
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8  12
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   9  12
#   1.2% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  10  12
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  11  12
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1  13
#   1.1% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2  13
#   0.9% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3  13
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4  13
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5  13
#   0.8% of the data on this baseline is now flagged
#   1.1% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7  13
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8  13
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   9  13
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  10  13
#   1.3% of the data on this baseline is now flagged
#   1.6% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  11  13
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  12  13
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   1  14
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   2  14
#   1.1% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   3  14
#   0.9% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   4  14
#   1.0% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   5  14
#   1.0% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   7  14
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   8  14
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline   9  14
#   1.0% of the data on this baseline is now flagged
#   1.4% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  10  14
#   1.2% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  11  14
#   1.0% of the data on this baseline is now flagged
#   1.2% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  12  14
#   1.1% of the data on this baseline is now flagged
#   1.5% of the data on this baseline is now flagged
# Do SumThreshold operation on baseline  13  14
#   1.0% of the data on this baseline is now flagged
#   1.3% of the data on this baseline is now flagged
# Applying changes to dataset
# Counts of correlations within selected channels:
#  channel  Originally  Currently
#  Good:      19285650   19226212    Changed to bad:      59438
#  Bad:        6949230    7008668    Changed to good:         0
#  26.7% of the data is now flagged
#
# basher - DEBUG : Returning output.
# miriad pgflag - INFO : Completed.
